# %%
import numpy as np
from specpol.ritz import sturm_liouville_bdd

# %%
sl_spec = dict()
sl_spec_dbm = dict()

# %%
sl_spec = sturm_liouville_bdd(lambda x: 0, (0, 1), 50, 321, (1, 1))

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax1 = fig.add_subplot()
ax1.scatter(sl_spec.real, [0]*len(sl_spec))
ax1.set_xlim(0, 1000)
# Out:
# (0.0, 1000.0)
